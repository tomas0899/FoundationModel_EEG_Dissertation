# %% [markdown]
# # XB47Y: DIM reduction
# gold

# %%
import pandas as pd

df_feat_ictalVspreictal_1min = pd.read_pickle("/home/tperezsanchez/FoundationModel_EEG_Dissertation/Main_project/results/XB47Y/Feature_ext/Part2_features/XB47Y_IN-normalized_npz_FP-fullnpz_W10s_PRE6to5min_ICT0to1min_GAPasINT_FINAL-PREvsSEIZ_20260504_v01_FEAT-TIME-FREQ_20260505_v01/XB47Y_IN-normalized_npz_FP-fullnpz_W10s_PRE6to5min_ICT0to1min_GAPasINT_FINAL-PREvsSEIZ_20260504_v01_FEAT-TIME-FREQ_20260505_v01_df_features_ictalVspreictal.pkl")

print(df_feat_ictalVspreictal_1min.head())
# Out:
#                    file_name  window_id  start_sample  end_sample          fs  \
# 0  XB47Y_41_preproc_full.npz       1278       2645460     2647530  207.031055
# 1  XB47Y_41_preproc_full.npz       1279       2647530     2649600  207.031055
# 2  XB47Y_41_preproc_full.npz       1280       2649600     2651670  207.031055
# 3  XB47Y_41_preproc_full.npz       1281       2651670     2653740  207.031055
# 4  XB47Y_41_preproc_full.npz       1282       2653740     2655810  207.031055
#
#    n_channels  window_sec                seizure_onsets  \
# 0           2          10  [2019-10-31 23:25:08.153000]
# 1           2          10  [2019-10-31 23:25:08.153000]
# 2           2          10  [2019-10-31 23:25:08.153000]
# 3           2          10  [2019-10-31 23:25:08.153000]
# 4           2          10  [2019-10-31 23:25:08.153000]
#
#               window_start_time               window_end_time  ...  \
# 0 2019-10-31 23:19:03.082999583 2019-10-31 23:19:13.081499583  ...
# 1 2019-10-31 23:19:13.081499583 2019-10-31 23:19:23.079999582  ...
# 2 2019-10-31 23:19:23.079999582 2019-10-31 23:19:33.078499582  ...
# 3 2019-10-31 23:19:33.078499582 2019-10-31 23:19:43.076999582  ...
# 4 2019-10-31 23:19:43.076999582 2019-10-31 23:19:53.075499581  ...
#
#    alpha_power_EEG_SQ_D_SQ_C beta_power_EEG_SQ_D_SQ_C  \
# 0                   0.002582                 0.019144
# 1                   0.025909                 0.075080
# 2                   0.008247                 0.142228
# 3                   0.005990                 0.156501
# 4                   0.006253                 0.167084
#
#   gamma_power_EEG_SQ_D_SQ_C  peak_frequency_EEG_SQ_D_SQ_C  \
# 0                  0.006566                      1.000150
# 1                  0.035583                      1.000150
# 2                  0.049720                      1.000150
# 3                  0.061811                     24.503676
# 4                  0.086315                     19.002850
#
#    delta_power_EEG_SQ_P_SQ_C  theta_power_EEG_SQ_P_SQ_C  \
# 0                   0.013596                   0.003118
# 1                   0.374413                   0.020533
# 2                   0.026109                   0.004368
# 3                   0.023547                   0.009824
# 4                   0.018473                   0.005101
#
#    alpha_power_EEG_SQ_P_SQ_C  beta_power_EEG_SQ_P_SQ_C  \
# 0                   0.007933                  0.021500
# 1                   0.039268                  0.397410
# 2                   0.020448                  0.253664
# 3                   0.015228                  0.274218
# 4                   0.012831                  0.262820
#
#    gamma_power_EEG_SQ_P_SQ_C  peak_frequency_EEG_SQ_P_SQ_C
# 0                   0.006653                      1.000150
# 1                   0.130566                      0.500075
# 2                   0.104950                     29.004351
# 3                   0.111887                     24.503676
# 4                   0.175828                     18.502775
#
# [5 rows x 41 columns]

# %%
for col in df_feat_ictalVspreictal_1min.columns:
    print(col)
# Out:
# file_name
# window_id
# start_sample
# end_sample
# fs
# n_channels
# window_sec
# seizure_onsets
# window_start_time
# window_end_time
# class_label
# label_name
# excluded_reason
# mean_EEG_SQ_D_SQ_C
# std_EEG_SQ_D_SQ_C
# var_EEG_SQ_D_SQ_C
# rms_EEG_SQ_D_SQ_C
# ptp_EEG_SQ_D_SQ_C
# line_length_EEG_SQ_D_SQ_C
# skew_EEG_SQ_D_SQ_C
# kurtosis_EEG_SQ_D_SQ_C
# mean_EEG_SQ_P_SQ_C
# std_EEG_SQ_P_SQ_C
# var_EEG_SQ_P_SQ_C
# rms_EEG_SQ_P_SQ_C
# ptp_EEG_SQ_P_SQ_C
# line_length_EEG_SQ_P_SQ_C
# skew_EEG_SQ_P_SQ_C
# kurtosis_EEG_SQ_P_SQ_C
# delta_power_EEG_SQ_D_SQ_C
# theta_power_EEG_SQ_D_SQ_C
# alpha_power_EEG_SQ_D_SQ_C
# beta_power_EEG_SQ_D_SQ_C
# gamma_power_EEG_SQ_D_SQ_C
# peak_frequency_EEG_SQ_D_SQ_C
# delta_power_EEG_SQ_P_SQ_C
# theta_power_EEG_SQ_P_SQ_C
# alpha_power_EEG_SQ_P_SQ_C
# beta_power_EEG_SQ_P_SQ_C
# gamma_power_EEG_SQ_P_SQ_C
# peak_frequency_EEG_SQ_P_SQ_C

# %% [markdown]
# ## 1. separate metadata from features

# %%
# Columns that are NOT EEG features
metadata_cols = [
    "file_name",
    "window_id",
    "start_sample",
    "end_sample",
    "fs",
    "n_channels",
    "window_sec",
    "seizure_onsets",
    "window_start_time",
    "window_end_time",
    "class_label",
    "label_name",
    "excluded_reason"
]

# Feature columns = everything except metadata
feature_cols = [col for col in df_feat_ictalVspreictal_1min.columns if col not in metadata_cols]

print("Number of feature columns:", len(feature_cols))
print(feature_cols)
# Out:
# Number of feature columns: 28
# ['mean_EEG_SQ_D_SQ_C', 'std_EEG_SQ_D_SQ_C', 'var_EEG_SQ_D_SQ_C', 'rms_EEG_SQ_D_SQ_C', 'ptp_EEG_SQ_D_SQ_C', 'line_length_EEG_SQ_D_SQ_C', 'skew_EEG_SQ_D_SQ_C', 'kurtosis_EEG_SQ_D_SQ_C', 'mean_EEG_SQ_P_SQ_C', 'std_EEG_SQ_P_SQ_C', 'var_EEG_SQ_P_SQ_C', 'rms_EEG_SQ_P_SQ_C', 'ptp_EEG_SQ_P_SQ_C', 'line_length_EEG_SQ_P_SQ_C', 'skew_EEG_SQ_P_SQ_C', 'kurtosis_EEG_SQ_P_SQ_C', 'delta_power_EEG_SQ_D_SQ_C', 'theta_power_EEG_SQ_D_SQ_C', 'alpha_power_EEG_SQ_D_SQ_C', 'beta_power_EEG_SQ_D_SQ_C', 'gamma_power_EEG_SQ_D_SQ_C', 'peak_frequency_EEG_SQ_D_SQ_C', 'delta_power_EEG_SQ_P_SQ_C', 'theta_power_EEG_SQ_P_SQ_C', 'alpha_power_EEG_SQ_P_SQ_C', 'beta_power_EEG_SQ_P_SQ_C', 'gamma_power_EEG_SQ_P_SQ_C', 'peak_frequency_EEG_SQ_P_SQ_C']

# %% [markdown]
# ## 2. Build matrix

# %%
X = df_feat_ictalVspreictal_1min[feature_cols].copy()
y = df_feat_ictalVspreictal_1min["class_label"].copy()

print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (483, 28)
# y shape: (483,)

# %% [markdown]
# ## 3. check for NaNs or inf

# %%
import numpy as np

print("NaNs per column:")
print(X.isna().sum())

print("Any infinite values?")
print(np.isinf(X).sum().sum())
# Out:
# NaNs per column:
# mean_EEG_SQ_D_SQ_C              0
# std_EEG_SQ_D_SQ_C               0
# var_EEG_SQ_D_SQ_C               0
# rms_EEG_SQ_D_SQ_C               0
# ptp_EEG_SQ_D_SQ_C               0
# line_length_EEG_SQ_D_SQ_C       0
# skew_EEG_SQ_D_SQ_C              0
# kurtosis_EEG_SQ_D_SQ_C          0
# mean_EEG_SQ_P_SQ_C              0
# std_EEG_SQ_P_SQ_C               0
# var_EEG_SQ_P_SQ_C               0
# rms_EEG_SQ_P_SQ_C               0
# ptp_EEG_SQ_P_SQ_C               0
# line_length_EEG_SQ_P_SQ_C       0
# skew_EEG_SQ_P_SQ_C              0
# kurtosis_EEG_SQ_P_SQ_C          0
# delta_power_EEG_SQ_D_SQ_C       0
# theta_power_EEG_SQ_D_SQ_C       0
# alpha_power_EEG_SQ_D_SQ_C       0
# beta_power_EEG_SQ_D_SQ_C        0
# gamma_power_EEG_SQ_D_SQ_C       0
# peak_frequency_EEG_SQ_D_SQ_C    0
# delta_power_EEG_SQ_P_SQ_C       0
# theta_power_EEG_SQ_P_SQ_C       0
# alpha_power_EEG_SQ_P_SQ_C       0
# beta_power_EEG_SQ_P_SQ_C        0
# gamma_power_EEG_SQ_P_SQ_C       0
# peak_frequency_EEG_SQ_P_SQ_C    0
# dtype: int64
# Any infinite values?
# 0

# %% [markdown]
# ## 4. Scale features before PCA
# PCA needs features to be in comparable scale

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

print("X_scaled shape:", X_scaled.shape)
# Out:
# X_scaled shape: (483, 28)

# %% [markdown]
# ## 5. Apply PCA. start with only 5 components first

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# PCA with all possible components
pca_full = PCA()
X_pca_full = pca_full.fit_transform(X_scaled)

# Explained variance
explained_var = pca_full.explained_variance_ratio_
cumulative_var = np.cumsum(explained_var)

# Print explained variance per PC
for i, (var, cum_var) in enumerate(zip(explained_var, cumulative_var), start=1):
    print(f"PC{i}: {var*100:.2f}% | cumulative: {cum_var*100:.2f}%")
# Out:
# PC1: 48.56% | cumulative: 48.56%
# PC2: 12.71% | cumulative: 61.28%
# PC3: 8.98% | cumulative: 70.26%
# PC4: 5.41% | cumulative: 75.67%
# PC5: 3.80% | cumulative: 79.47%
# PC6: 3.56% | cumulative: 83.03%
# PC7: 3.15% | cumulative: 86.18%
# PC8: 2.83% | cumulative: 89.01%
# PC9: 2.25% | cumulative: 91.26%
# PC10: 1.77% | cumulative: 93.03%
# PC11: 1.30% | cumulative: 94.34%
# PC12: 1.23% | cumulative: 95.56%
# PC13: 1.10% | cumulative: 96.66%
# PC14: 1.05% | cumulative: 97.71%
# PC15: 0.85% | cumulative: 98.56%
# PC16: 0.46% | cumulative: 99.02%
# PC17: 0.27% | cumulative: 99.29%
# PC18: 0.20% | cumulative: 99.49%
# PC19: 0.16% | cumulative: 99.66%
# PC20: 0.14% | cumulative: 99.79%
# PC21: 0.07% | cumulative: 99.86%
# PC22: 0.06% | cumulative: 99.92%
# PC23: 0.03% | cumulative: 99.95%
# PC24: 0.03% | cumulative: 99.98%
# PC25: 0.01% | cumulative: 99.99%
# PC26: 0.01% | cumulative: 100.00%
# PC27: 0.00% | cumulative: 100.00%
# PC28: 0.00% | cumulative: 100.00%

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=8)

X_pca = pca.fit_transform(X_scaled)

print("X_pca shape:", X_pca.shape)
# Out:
# X_pca shape: (483, 8)

# %%
explained_variance = pca.explained_variance_ratio_

for i, var in enumerate(explained_variance, start=1):
    print(f"PC{i}: {var:.4f} ({var*100:.2f}%)")

print("Total explained variance:", explained_variance.sum())
# Out:
# PC1: 0.4856 (48.56%)
# PC2: 0.1271 (12.71%)
# PC3: 0.0898 (8.98%)
# PC4: 0.0541 (5.41%)
# PC5: 0.0380 (3.80%)
# PC6: 0.0356 (3.56%)
# PC7: 0.0315 (3.15%)
# PC8: 0.0283 (2.83%)
# Total explained variance: 0.8901406892700106

# %% [markdown]
# ## 6. Final dataframe: windows x PCA

# %%
import pandas as pd

pca_cols = [f"PC{i+1}" for i in range(X_pca.shape[1])]

df_pca = pd.DataFrame(
    X_pca,
    columns=pca_cols,
    index=df_feat_ictalVspreictal_1min.index
)

df_pca.head()
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0 -3.846860 -1.393994 -1.217089 -0.159295  0.215043 -0.108806  0.036614
# 1 -0.781845  2.911585  3.021306 -0.758981  0.856212 -0.648562  1.084345
# 2 -2.125904 -1.431596  0.113957 -0.801890 -0.240469 -0.030201  0.424771
# 3 -1.925519 -2.854785 -0.084221 -0.951348  0.855354 -2.794150  3.413149
# 4 -2.024074 -2.600239 -0.313672 -0.826503  0.633583 -1.648342  3.070438
#
#         PC8
# 0  0.454819
# 1  1.725959
# 2  0.469756
# 3 -2.580673
# 4 -1.720771

# %% [markdown]
# ## 7. ADD metadata again

# %%
df_windows_pca = pd.concat(
    [
        df_feat_ictalVspreictal_1min[metadata_cols].reset_index(drop=True),
        df_pca.reset_index(drop=True)
    ],
    axis=1
)

df_windows_pca.head()
# Out:
#                    file_name  window_id  start_sample  end_sample          fs  \
# 0  XB47Y_41_preproc_full.npz       1278       2645460     2647530  207.031055
# 1  XB47Y_41_preproc_full.npz       1279       2647530     2649600  207.031055
# 2  XB47Y_41_preproc_full.npz       1280       2649600     2651670  207.031055
# 3  XB47Y_41_preproc_full.npz       1281       2651670     2653740  207.031055
# 4  XB47Y_41_preproc_full.npz       1282       2653740     2655810  207.031055
#
#    n_channels  window_sec                seizure_onsets  \
# 0           2          10  [2019-10-31 23:25:08.153000]
# 1           2          10  [2019-10-31 23:25:08.153000]
# 2           2          10  [2019-10-31 23:25:08.153000]
# 3           2          10  [2019-10-31 23:25:08.153000]
# 4           2          10  [2019-10-31 23:25:08.153000]
#
#               window_start_time               window_end_time  ...  \
# 0 2019-10-31 23:19:03.082999583 2019-10-31 23:19:13.081499583  ...
# 1 2019-10-31 23:19:13.081499583 2019-10-31 23:19:23.079999582  ...
# 2 2019-10-31 23:19:23.079999582 2019-10-31 23:19:33.078499582  ...
# 3 2019-10-31 23:19:33.078499582 2019-10-31 23:19:43.076999582  ...
# 4 2019-10-31 23:19:43.076999582 2019-10-31 23:19:53.075499581  ...
#
#    label_name excluded_reason       PC1       PC2       PC3       PC4  \
# 0    preictal            None -3.846860 -1.393994 -1.217089 -0.159295
# 1    preictal            None -0.781845  2.911585  3.021306 -0.758981
# 2    preictal            None -2.125904 -1.431596  0.113957 -0.801890
# 3    preictal            None -1.925519 -2.854785 -0.084221 -0.951348
# 4    preictal            None -2.024074 -2.600239 -0.313672 -0.826503
#
#         PC5       PC6       PC7       PC8
# 0  0.215043 -0.108806  0.036614  0.454819
# 1  0.856212 -0.648562  1.084345  1.725959
# 2 -0.240469 -0.030201  0.424771  0.469756
# 3  0.855354 -2.794150  3.413149 -2.580673
# 4  0.633583 -1.648342  3.070438 -1.720771
#
# [5 rows x 21 columns]

# %%
print(df_windows_pca.shape)
print(df_windows_pca.columns)
# Out:
# (483, 21)
# Index(['file_name', 'window_id', 'start_sample', 'end_sample', 'fs',
#        'n_channels', 'window_sec', 'seizure_onsets', 'window_start_time',
#        'window_end_time', 'class_label', 'label_name', 'excluded_reason',
#        'PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'PC7', 'PC8'],
#       dtype='object')

# %%
# Sanity check:Same number of rows as original df
print(df_feat_ictalVspreictal_1min.shape[0] == df_windows_pca.shape[0])
# Out:
# True

# %% [markdown]
# ## 8. export as pkl

# %%
from pathlib import Path

output_dir = Path("/home/tperezsanchez/FoundationModel_EEG_Dissertation/Main_project/results/XB47Y/Feature_ext/Part2_features/XB47Y_IN-normalized_npz_FP-fullnpz_W10s_PRE6to5min_ICT0to1min_GAPasINT_FINAL-PREvsSEIZ_20260504_v01_FEAT-TIME-FREQ_20260505_v01/")
output_dir.mkdir(parents=True, exist_ok=True)

output_path = output_dir / "df_windowsXB47Y_pca.pkl"

df_windows_pca.to_pickle(output_path)

print(f"Saved PCA dataframe to: {output_path}")
print("Shape:", df_windows_pca.shape)
# Out:
# Saved PCA dataframe to: /home/tperezsanchez/FoundationModel_EEG_Dissertation/Main_project/results/XB47Y/Feature_ext/Part2_features/XB47Y_IN-normalized_npz_FP-fullnpz_W10s_PRE6to5min_ICT0to1min_GAPasINT_FINAL-PREvsSEIZ_20260504_v01_FEAT-TIME-FREQ_20260505_v01/df_windowsXB47Y_pca.pkl
# Shape: (483, 21)
