# %% [markdown]
# # Mix both readers to match the seizure time
# Ashes to ashes - David Bowie

# %%
pip install h5py
# Out:
# Collecting h5py
#   Downloading h5py-3.15.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: numpy>=1.21.2 in /home/tperezsanchez/micromamba/envs/domain_expansion/lib/python3.10/site-packages (from h5py) (2.2.6)
# Downloading h5py-3.15.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 95.1 MB/s  0:00:00
# Installing collected packages: h5py
# Successfully installed h5py-3.15.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

df_diary = pd.read_csv('/home/tperezsanchez/FoundationModel_EEG_Dissertation/EEG_data_vis/data/Working/XB47Y/preprocessCSV_XB47Y/diary.csv')

# Para ver las primeras filas
print(df_diary.head())
# Out:
#              Timestamp          timestamp_formatted
# 0  2019-10-31 23:05:29  [[2019, 10, 31, 23, 5, 29]]
# 1  2019-11-01 10:15:24  [[2019, 11, 1, 10, 15, 24]]
# 2  2019-11-01 16:00:14   [[2019, 11, 1, 16, 0, 14]]
# 3  2019-11-08 22:50:24  [[2019, 11, 8, 22, 50, 24]]
# 4  2019-11-09 11:20:52  [[2019, 11, 9, 11, 20, 52]]

# %% [markdown]
# ## Functions

# %%
# first version
import re
import numpy as np

def date_checker(date1, date2):
    def extract_numbers(val):
  
        val_str = str(val)
        
        numbers = re.findall(r'\d+', val_str)
        
        return [int(n) for n in numbers]

    try:
        list1 = extract_numbers(date1)
        list2 = extract_numbers(date2)
        
        return list1 == list2
    except Exception as e:
        print(f"Error comparando: {e}")
        return False

#test
formato_comas = "[[2019, 10, 31, 23,    5, 29]"
formato_espacios = "[[2019   10   31            23   5   29]]"

if date_checker(formato_comas, formato_espacios):
    print("si")
else:
    print("no")
# Out:
# si

# %%
#second version with time range 5 min
import re
from datetime import datetime, timedelta

def date_checker(date1, date2):
    def to_datetime(val):
        # Extraemos los números: [año, mes, día, hora, minuto, segundo]
        val_str = str(val)
        nums = [int(n) for n in re.findall(r'\d+', val_str)]
        
        # Creamos el objeto datetime (asumiendo el orden estándar de tus strings)
        # Tomamos los primeros 6 elementos por si el string tiene extras
        return datetime(nums[0], nums[1], nums[2], nums[3], nums[4], nums[5])

    try:
        dt1 = to_datetime(date1)
        dt2 = to_datetime(date2)
        
        # Calculamos la diferencia absoluta
        diferencia = abs(dt1 - dt2)
        
        # Verificamos si la diferencia es menor o igual a 5 minutos
        return diferencia <= timedelta(minutes=5)
        
    except Exception as e:
        print(f"Error comparando: {e}")
        return False

# --- Pruebas ---
# Caso 1: Idénticas
fecha_a = "[[2019, 10, 31, 23, 5, 29]"
fecha_b = "[[2019  10  31            23   5   29]]"

# Caso 2: Con 4 minutos de diferencia
fecha_c = "[[2019, 10, 31, 23, 0, 29]" 

print(f"¿Son iguales? {date_checker(fecha_a, fecha_b)}") # True
print(f"¿Están en el rango de 5 min? {date_checker(fecha_a, fecha_c)}") # True
# Out:
# ¿Son iguales? True
# ¿Están en el rango de 5 min? True

# %%
import os
import numpy as np
from datetime import datetime
from scipy.io import loadmat

def save_eeg_table_with_T0(mat_path, EEG_Table, output_dir="."):
    """
    Save an EEG table to CSV using the .mat filename and the T0 timestamp.

    Parameters
    ----------
    mat_path : str
        Full path to the .mat file.
    EEG_Table : pandas.DataFrame
        DataFrame containing Time + EEG channels.
    output_dir : str, optional
        Directory where the CSV will be saved (default: current directory).

    Returns
    -------
    csv_path : str
        Full path to the saved CSV file.
    """

    # Load .mat to access header
    mat_data = loadmat(mat_path)
    hdr = mat_data["hdr"]

    # Extract T0
    orig = hdr["orig"][0,0]
    T0 = np.array(orig["T0"][0,0]).astype(int).flatten()

    start_time = datetime(
        year=T0[0],
        month=T0[1],
        day=T0[2],
        hour=T0[3],
        minute=T0[4],
        second=T0[5]
    )

    # Format timestamp
    date_str = start_time.strftime("%Y%m%d_%H%M%S")

    # Base filename (without .mat)
    base_name = os.path.splitext(os.path.basename(mat_path))[0]

    # Final CSV name
    csv_name = f"{base_name}_{date_str}.csv"
    csv_path = os.path.join(output_dir, csv_name)

    # Save
    EEG_Table.to_csv(csv_path, index=False)

    return csv_path
# how to use it:
#csv_path = save_eeg_table_with_T0(
#    mat_path="/home/tperezsanchez/data/XB47Y_1.mat",
#    EEG_Table=EEG_Table,
#    output_dir="/home/tperezsanchez/data/csv"
#)

# %%
import os
import h5py
from scipy.io import loadmat

folder_path = "/home/tperezsanchez/FoundationModel_EEG_Dissertation/EEG_data_vis/data/Working/XB47Y/"

for filename in os.listdir(folder_path):
    if not filename.lower().endswith(".mat") or filename.startswith('.'):
        continue
        
    file_path = os.path.join(folder_path, filename)
    
    try:
        # 1. Try standard Scipy loading (v4, v6, v7)
        data_XB47Y = loadmat(file_path)
        hdr = data_XB47Y["hdr"]
        # Scipy loads structs as numpy object arrays
        orig = hdr["orig"][0, 0]
        T0 = orig["T0"][0, 0]
        for seizure_date in df_diary["timestamp_formatted"]:
            #print(seizure_date)
            #print(T0)
            if date_checker(seizure_date,T0):
                print('hola')
                fs = float(hdr['Fs'][0,0]) # transform to float32, this is the sampling freq/rate
                channels_raw = hdr['label'][0,0] # chanells, in this case they are two
                channels_raw.shape # 2 rows and 1 columns 
                channels_raw.shape[0] # I select only the channels
                channels = []
                for row in channels_raw:
                    channels.append(str(row[0][0]))
                    # row[0][0] --> EEG SQ_D-SQ_C
                signal = np.asarray(data_XB47Y['data'])
                if signal.shape[1] != len(channels) and signal.shape[0] == len(channels):
                    signal = signal.T
                # Converst signal from .mat into a numpy array
                
                
                #number of samples
                n_samples = signal.shape[0] 
                print("number of samples (rows):",n_samples)
                
                # Δt = 1 / freq ≈ 0.00483 s
                time = np.arange(n_samples) / fs 
                
                # create data frame:
                EEG_Table = pd.DataFrame(signal, columns=channels)
                EEG_Table.insert(0, "Time", time)
                
                csv_path = save_eeg_table_with_T0(
                mat_path=file_path,
                EEG_Table=EEG_Table,
                output_dir="/home/tperezsanchez/EEG_data_vis/results/Seiz_test_04022026/"
            )
    except (ValueError, NotImplementedError):
        # 2. Try HDF5 loading (v7.3)
        # Note: h5py handles the data structure differently (often transposed)
        with h5py.File(file_path, 'r') as f:
            # Accessing HDF5 datasets is like a dictionary
            # Depending on how the struct was saved, you may need to adjust indices
            hdr = f['hdr']
            orig = hdr['orig']
            # HDF5 often stores references; this is a simplified access:
            T0 = f[orig['T0'][0, 0]][()] 
            for seizure_date in df_diary["timestamp_formatted"]:
                print(seizure_date)
            
    #print(f"File: {filename} | T0: {T0}")

# %% [markdown]
# ### VERSION 2

# %%
#VERSION 2
import os
import h5py
import numpy as np
import pandas as pd
from scipy.io import loadmat

folder_path = "/home/tperezsanchez/FoundationModel_EEG_Dissertation/EEG_data_vis/data/Working/XB47Y/"

for filename in os.listdir(folder_path):
    if not filename.lower().endswith(".mat") or filename.startswith('.'):
        continue
        
    file_path = os.path.join(folder_path, filename)
    data_loaded = False
    
    # --- PASO 1: CARGAR EL ARCHIVO (Solamente carga) ---
    try:
        data_mat = loadmat(file_path)
        hdr = data_mat["hdr"]
        # Extraer T0 para Scipy
        T0 = hdr["orig"][0, 0]["T0"][0, 0]
        fs = float(hdr['Fs'][0,0].item())
        signal = np.asarray(data_mat['data'])
        channels_raw = hdr['label'][0,0]
        is_hdf5 = False
        data_loaded = True
    except (ValueError, NotImplementedError, KeyError):
        try:
            # Intento con HDF5 si Scipy falla
            with h5py.File(file_path, 'r') as f:
                # Nota: Acceder a HDF5 requiere dereferenciar objetos
                # Esto es un ejemplo, v7.3 suele ser más complejo:
                T0_ref = f['hdr']['orig']['T0'][0, 0]
                T0 = f[T0_ref][()] 
                # ... (habría que cargar el resto de variables igual)
                is_hdf5 = True
                data_loaded = True
        except Exception as e:
            print(f"No se pudo cargar {filename}: {e}")
            continue

    # --- PASO 2: PROCESAR (Fuera del Try de carga) ---
    if data_loaded:
        for seizure_date in df_diary["timestamp_formatted"]:
            # Usando la función date_checker con Regex que hicimos antes
            if date_checker(T0, seizure_date):
                print(f"¡Match! Procesando {filename} para la fecha {seizure_date}")
                
                # Extraer canales
                channels = [str(row[0][0]) for row in channels_raw]
                
                # Corregir transposición de señal si es necesario
                if signal.shape[1] != len(channels) and signal.shape[0] == len(channels):
                    signal = signal.T
                
                n_samples = signal.shape[0]
                time = np.arange(n_samples) / fs 
                
                # Crear DataFrame
                EEG_Table = pd.DataFrame(signal, columns=channels)
                EEG_Table.insert(0, "Time", time)
                
                # Guardar
                save_eeg_table_with_T0(
                    mat_path=file_path,
                    EEG_Table=EEG_Table,
                    output_dir="/home/tperezsanchez/EEG_data_vis/results/Seiz_test_04022026/"
                )

# %%
for filename in os.listdir(folder_path):
    if not filename.lower().endswith(".mat") or filename.startswith('.'):
        continue
        
    file_path = os.path.join(folder_path, filename)
    print(f"\n🔍 Analizando: {filename}")
    
    data_loaded = False
    
    try:
        data_mat = loadmat(file_path)
        hdr = data_mat["hdr"]
        T0 = hdr["orig"][0, 0]["T0"][0, 0]
        # Usamos item() para evitar el warning
        fs = float(hdr['Fs'][0,0].item())
        signal = np.asarray(data_mat['data'])
        channels_raw = hdr['label'][0,0]
        data_loaded = True
        print(f"  ✅ Cargado con Scipy. T0 encontrado: {T0}")
    except Exception as e:
        print(f"  ❌ Falló Scipy: {type(e).__name__} - {e}")
        # Aquí podrías poner el bloque de h5py si sabes que tienes archivos v7.3
        continue

    if data_loaded:
        match_encontrado = False
        for seizure_date in df_diary["timestamp_formatted"]:
            if date_checker(seizure_date, T0):
                match_encontrado = True
                print(f"  🎯 ¡MATCH! Fecha diario: {seizure_date} == T0: {T0}")
                
                try:
                    # Debug de canales
                    print(f"  📏 Dimensiones señal: {signal.shape}")
                    channels = [str(row[0][0]) for row in channels_raw]
                    print(f"  🏷️ Canales extraídos: {channels}")

                    if signal.shape[1] != len(channels) and signal.shape[0] == len(channels):
                        signal = signal.T
                    
                    n_samples = signal.shape[0]
                    time = np.arange(n_samples) / fs 
                    
                    EEG_Table = pd.DataFrame(signal, columns=channels)
                    EEG_Table.insert(0, "Time", time)
                    
                    print(f"  💾 Intentando guardar CSV...")
                    save_eeg_table_with_T0(
                        mat_path=file_path,
                        EEG_Table=EEG_Table,
                        output_dir="/home/tperezsanchez/EEG_data_vis/results/Seiz_test_04022026/"
                    )
                    print(f"  🎉 Guardado con éxito.")
                except Exception as e:
                    print(f"  💥 Error procesando datos internos: {e}")
        
        if not match_encontrado:
            print(f"  ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.")
# Out:
# 🔍 Analizando: XB47Y_38.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   10   30    1   54   13]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_34.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12   13   10   49   58]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_133.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   17   16   24    8]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_110.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11    6    7   42   43]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_15.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12    2   21   14   31]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_129.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   16   11   25   56]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_79.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   19    6   17    6]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_159.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   29   17   30   10]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_146.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11    8    7    9   40]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_98.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   10   30    7   47   44]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_36.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12   13   11   13   30]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_59.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11    9   12   10   27]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_143.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   24   16   17    1]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_13.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12    2   15    7   39]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_108.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11    4   19    1   16]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_180.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12   10   11   34   44]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_152.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   27   21   58   13]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_176.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12    9   13   43   56]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_161.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12    1   20   13   12]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_78.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   19    0   17    6]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_115.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11    7   13   48   23]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_62.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   11    7   37   45]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_156.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   29   13   40   16]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_71.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   15   13   40    3]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_149.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   27    7   41   29]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_21.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12    5    2   30   49]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_118.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   10   15   25    2]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_60.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11    9   18   10   27]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_82.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   19   23   18   41]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_76.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   18   15    4   54]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_130.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   16   17   25   56]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_155.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   29   11   59   52]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_119.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   10   21   25    2]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_12.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12    2    9    7   39]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_19.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12    4   15   52   32]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_33.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12   11    7   16   11]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_141.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   23    2    4   35]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_147.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   25   11   50   37]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_63.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   11   13   37   45]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_116.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11    7   19   34   58]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_89.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   23   12    0   24]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_113.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11    7    1   42   43]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_4.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   27    2    4   27]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_7.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   28   22   59   11]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_117.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11    8    1   34   58]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_68.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   13   19   38   44]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_11.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12    1    6    5   35]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_127.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   14   19   33   26]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_84.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   21   10   26   53]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_109.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11    5    1    1   16]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_3.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   26   20    4   27]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_64.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   11   19   37   45]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_40.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   10   31   13   46    5]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_57.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11    9    3    0   15]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_134.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   17   22   24    8]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_22.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12    6   10    7    2]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_122.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   12   13   34    7]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_16.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12    2   21   52    0]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_112.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11    6   19   42   43]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_153.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   28    3   58   13]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_49.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11    5    7   39   22]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_17.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12    3    3   52    0]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_29.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12   10   18   17   39]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_125.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   14    7   33   26]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_73.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   16    1   40    3]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_44.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11    2   23    4   32]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_106.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11    4    7   46   20]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_28.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12   10   12   17   39]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_158.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   29   16   56   56]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_85.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   21   16   26   53]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_88.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   22    5   46   14]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_173.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12    7   22   29    1]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_77.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   18   21    4   54]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_177.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12    9   19   11   25]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_23.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12    6   16    7    2]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_67.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   13   13   38   44]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_160.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12    1   14   13   12]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_168.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12    5   15   53   49]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_179.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12   10    7   11   25]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_87.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   21   23   46   14]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_162.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12    2    2   13   12]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_9.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   30   18    5   35]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_140.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   22   20    4   35]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_42.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11    1    1   46    5]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_43.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11    2   17    4   32]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_126.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   14   13   33   26]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_37.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   10   29   19   54   13]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_24.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12    6   22    7    2]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_148.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   25   21   17    3]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_101.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   10   31    1   47   44]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_8.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   29    4   59   11]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_181.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12   11   10    0   59]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_139.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   22   14    4   35]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_93.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   24    3   40    8]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_157.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   29   16   34   48]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_120.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   11    3   25    2]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_100.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   10   30   19   47   44]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_121.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   12    7   34    7]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_183.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12   11   20   12   27]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_107.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11    4   13   46   20]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_81.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   19   18   17    6]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_124.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   13    1   34    7]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_99.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   10   30   13   47   44]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_128.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   15    1   33   26]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_97.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   21   23   38    9]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_50.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11    5   13   39   22]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_164.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12    3   16    0   38]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_136.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   20   15   52    2]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_103.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11    1   13   43   13]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_163.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12    3   10    0   38]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_174.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12    8    4   29    1]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_83.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   20    5   18   41]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_32.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12   12    0   15   25]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_96.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   21   10   21   58]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_137.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   20   21   52    2]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_31.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12   11    6   17   39]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_86.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   21   22   26   53]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_46.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11    3   13   21   22]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_41.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   10   31   19   46    5]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_65.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   12    1   37   45]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_151.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   27   19   41   29]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_104.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11    1   19   43   13]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_175.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12    9   10   18   49]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_35.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   10   29    9   31    4]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_74.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   16    7   40    3]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_111.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11    6   13   42   43]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_14.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12    2   21    7   39]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_54.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11    8   13   40   20]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_165.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12    3   22    0   38]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_144.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   24   22   17    1]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_26.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12    8   17   51   57]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_132.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   17   10   41    5]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_102.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11    1    7   43   13]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_150.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   27   13   41   29]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_27.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12    8   23   51   57]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_6.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   28   16   59   11]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_75.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   18    9    4   54]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_92.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   23   21   40    8]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_172.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12    7   16   29    1]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_123.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   12   19   34    7]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_135.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   20    9   52    2]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_5.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   28   10   59   11]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_48.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11    4    1   21   22]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_169.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12    5   21   53   49]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_58.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11    9    9    0   15]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_171.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12    6    5   41    9]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_20.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12    4   20   30   49]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_39.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   10   31    7   46    5]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_80.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   19   12   17    6]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_154.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   29   10   49   11]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_178.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12   10    1   11   25]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_47.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11    3   19   21   22]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_91.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   23   15   40    8]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_105.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11    2    1   43   13]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_66.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   13    7   38   44]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_95.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   25    7   47   19]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_166.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12    4    4    0   38]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_10.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12    1    0    5   35]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_55.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11    8   15    0   15]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_52.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11    6    1   39   22]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_94.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   24    9   40    8]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_138.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   22    8    4   35]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_72.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   15   19   40    3]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_167.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12    5    9   53   49]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_18.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12    4    9   52   32]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_56.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11    8   21    0   15]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_90.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   23   14   10   36]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_61.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   10    0   10   27]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_53.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11    8    7   40   20]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_114.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11    7    7   48   23]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_170.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12    5   23   41    9]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_145.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   25    4   17    1]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_45.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11    3   13   16    8]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_1.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   26    7   32    3]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_30.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12   11    0   17   39]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_2.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   26   11   53   17]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_182.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12   11   16    0   59]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_51.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11    5   19   39   22]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_131.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   16   23   25   56]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_69.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   14    1   38   44]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_70.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   15    7   40    3]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_142.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   11   23    8    4   35]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.
#
# 🔍 Analizando: XB47Y_25.mat
#   ✅ Cargado con Scipy. T0 encontrado: [[2019   12    7    4    7    2]]
#   ⚠️ No se encontró ninguna coincidencia en el diario para este archivo.

# %%
hdr = data_XB47Y_1['hdr']
orig = hdr['orig'][0,0]
T0 = orig['T0'][0,0]
